// %% [markdown]
// # 📙 Tipos de Datos y Variables

// %% [markdown]
// ## Tabla de Contenido
//
// - [1 - Instalar Java](#1)
// - [2 - Tipos de Datos](#2)
//   - [2.1 - Datos Primitivos](#2.1)
//   - [2.2 - Espacio en Memoria](#2.2)
//   - [2.3 - Desborde de Memoria](#2.3)
//   - [2.4 - Constantes](#2.4)

// %% [markdown]
// <a name='1'></a>
// ## Instalar Java

// %% [markdown]
// <div class="admonition warning" style="padding: 10px">
//     <p class="title">Descargar el kernel</p>
// <p>Ejecuta la siguiente celda. No la modifiques!</p>
// </div>

// %%
%%sh
wget -q https://github.com/SpencerPark/IJava/releases/download/v1.3.0/ijava-1.3.0.zip
unzip -q ijava-1.3.0.zip
python install.py

wget -qO- https://gist.github.com/SpencerPark/e2732061ad19c1afa4a33a58cb8f18a9/archive/b6cff2bf09b6832344e576ea1e4731f0fb3df10c.tar.gz | tar xvz --strip-components=1
python install_ipc_proxy_kernel.py --kernel=java --implementation=ipc_proxy_kernel.py
// Out:
// Installed java kernel into "/usr/local/share/jupyter/kernels/java"
// e2732061ad19c1afa4a33a58cb8f18a9-b6cff2bf09b6832344e576ea1e4731f0fb3df10c/install_ipc_proxy_kernel.py
// e2732061ad19c1afa4a33a58cb8f18a9-b6cff2bf09b6832344e576ea1e4731f0fb3df10c/ipc_proxy_kernel.py
// Moving java kernel from /usr/local/share/jupyter/kernels/java...
// Wrote modified kernel.json for java_tcp in /usr/local/share/jupyter/kernels/java_tcp/kernel.json
// Installing the proxy kernel in place of java in /usr/local/share/jupyter/kernels/java
// Installed proxy kernelspec: {"argv": ["/usr/bin/python3", "/usr/local/share/jupyter/kernels/java/ipc_proxy_kernel.py", "{connection_file}", "--kernel=java_tcp"], "env": {}, "display_name": "Java", "language": "java", "interrupt_mode": "message", "metadata": {}}
// Proxy kernel installed. Go to 'Runtime > Change runtime type' and select 'java'
// ...

// %% [markdown]
// <div class="admonition warning" style="padding: 10px">
//     <p class="title">Instrucciones para activar el kernel</p>
// <p>Dirigite a <code>Entorno de ejecución</code> > <code>Cambiar tipo de entorno de ejecución</code> > Elige la opción <code>Java</code> > Da click en <code>Guardar</code></p>
// </div>

// %% [markdown]
// <a name='2'></a>
// ## Tipos de Datos

// %% [markdown]
// <a name='2.1'></a>
// ### Datos Primitivos

// %% [markdown]
// ![image.png](data:image/png;base64,...)

// %%
// Entero de tipo byte
byte numByte = 2;
System.out.println(numByte);
// Out:
// 2

// %%
// Erro en asiganción de tipo byte
byte numByte2 = 255;
System.out.println(numByte2);
// Out:
// |   byte numByte2 = 255;
// incompatible types: possible lossy conversion from int to byte

// %%
// Entero de tipo int
int numero_1 = 5;
System.out.println(numero_1);
// Out:
// 5

// %%
// Entero de tipo short
short numero_2 = 5;
System.out.println(numero_2);
// Out:
// 5

// %%
// Erro en asiganción de tipo short
short numShort = 32_768;
System.out.println(numShort);
// Out:
// |   short numShort = 32_768;
// incompatible types: possible lossy conversion from int to short

// %%
// Entero de tipo long
long numero_3 = 23456;
System.out.println(numero_3);
// Out:
// 23456

// %%
// Punto flotante de tipo float
float numero_4 = 54.6f;
System.out.println(numero_4);
// Out:
// 54.6

// %%
// Punto flotante de tipo double
double numero_5 = 54.6;
System.out.println(numero_5);

// Punto flotante de tipo double
double numero_5 = 13.1d;
System.out.println(numero_5);
// Out:
// 54.6
// 13.1

// %%
// Carácter
char letra_1 = 'B';
System.out.println(letra_1);
// Out:
// B

// %%
// Booleano
boolean bool_1 = true;
System.out.println(bool_1);
// Out:
// true

// %% [markdown]
// <a name='2.2'></a>
// ### Espacio en memoria

// %%
System.out.println("Tamaño de byte: " + (Byte.SIZE/8) + " bytes.");
System.out.println("Tamaño de short: " + (Short.SIZE/8) + " bytes.");
System.out.println("Tamaño de int: " + (Integer.SIZE/8) + " bytes.");
System.out.println("Tamaño de long: " + (Long.SIZE/8) + " bytes.");
System.out.println("Tamaño de char: " + (Character.SIZE/8) + " bytes.");
System.out.println("Tamaño de float: " + (Float.SIZE/8) + " bytes.");
System.out.println("Tamaño de double: " + (Double.SIZE/8) + " bytes.");
// Out:
// Tamaño de byte: 1 bytes.
// Tamaño de short: 2 bytes.
// Tamaño de int: 4 bytes.
// Tamaño de long: 8 bytes.
// Tamaño de char: 2 bytes.
// Tamaño de float: 4 bytes.
// Tamaño de double: 8 bytes.

// %% [markdown]
// <a name='2.3'></a>
// ### Desborde de Memoria

// %%
short num1 = 32767;
System.out.println(num1);
// Out:
// 32767

// %%
short num2 = 32768;
System.out.println(num2);
// Out:
// |   short num2 = 32768;
// incompatible types: possible lossy conversion from int to short

// %%
int num3 = 32768;
System.out.println(num3);
// Out:
// 32768

// %%
byte num=127;
System.out.println(num);
// Out:
// 127

// %% [markdown]
// <a name='2.4'></a>
// ### Constantes
//
// **En los notebooks de Colab las constantes no funcionan, sin embargo, en otros IDEs como IntelliJ funcionan correctamente.**

// %% [markdown]
// Asignamos una valor que núnca cambiará:
//
//     final double PI = 3.141592653589793238;
//
// Si intentamos modificar su valor no será posible:
//
//     PI = 3.555;
//
//     Error: Cannot assign a value to final variable 'PI'

// %% [markdown]
// Otro ejemplo

// %% [markdown]
//     final char LetraA = 'A';
//
//     LetraA = 'B';
//
//     Error: Cannot assign a value to final variable 'LetraA'

// %% [markdown]
// Ejemplo en Colab (**Recuerda que no funciona**)

// %%
final int constanteEntera = 5;
constanteEntera = 6;
System.out.println(constanteEntera);
// Out:
// 6
